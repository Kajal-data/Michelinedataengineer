# %% [markdown]
# # Prerequisites

# %% [markdown]
# ## Load 'employee.csv' into DataFrame

# %%
employee_df = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sendbox/dataset-20260601T053440Z-3-001/dataset/employee.csv",
    header=True,
    inferSchema=True,
    sep="|",
    quote= "'",
    
)
employee_df.display()

# %% [markdown]
# #Selecting Columns

# %% [markdown]
# ## Using String Object

# %%
employee_df = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sendbox/dataset-20260601T053440Z-3-001/dataset/employee.csv",
    header=True,
    inferSchema=True,
    sep="|",
    quote= "'",
)
employee_df.select("id","name","gen").display()

# %% [markdown]
# ## Using Column Object

# %%
employee_df = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sendbox/dataset-20260601T053440Z-3-001/dataset/employee.csv",
    header=True,
    inferSchema=True,
    sep="|",
    quote= "'",
)
# employee_df.select("id","name","gen").display()
from pyspark.sql.functions import col
employee_df.select(col("id"),col("name").alias(f"name")).display()

# %%
employee_df.columns

# %% [markdown]
# # Exclude Columns

# %% [markdown]
# ### Imperative Style

# %%
employee_df = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sendbox/dataset-20260601T053440Z-3-001/dataset/employee.csv",
    header=True,
    inferSchema=True,
    sep="|",
)
columns_to_exclude = ["gen"]
columns_to_include = []
for columns in employee_df.columns:
    if columns not in columns_to_exclude:
        columns_code_include.append(columns)
employee_df.select(*columns_code_include).display()

# %% [markdown]
# ### Functional Style

# %%
columns_to_exclude = ["dob", "gen"]
columns_to_include = list(
    filter(lambda column: column not in columns_to_exclude, employee_df.columns)
)
employee_df.select(*columns_to_include).display()
employee_df

# %% [markdown]
# ### Composition Style(Recommended)

# %%
columns_to_exclude = ["doj", "gen"]
columns_to_include = [column for column in employee_df.columns if column not in columns_to_exclude]
employee_df.select(*columns_to_include).display()

# %% [markdown]
# # Filter operation

# %%
#display(employee_df.filter(col("gen")=="M"))
employee_df = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sendbox/dataset-20260601T053440Z-3-001/dataset/employee.csv",
    header=True,
    inferSchema=True,
    sep="|",
)
employee_df.filter(col("gen")=="F").select("name","id").display()

# %% [markdown]
# ### Filter gender and experience

# %%
#display(employee_df_filter(col("gen")== "M")
from pyspark.sql.functions import col
employee_df.filter(col("gen") == "M").select("name","id").display()

# %%
#display(employee_df.filter(col("gen")=="M"))
employee_df = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sendbox/dataset-20260601T053440Z-3-001/dataset/employee.csv",
    header=True,
    inferSchema=True,
    sep="|",
)
employee_df.filter(col("gen")=="F").filter(col("exp") > 2).select(col("name")).display()

# %% [markdown]
# ### Filter company name

# %%
employee_df = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sendbox/dataset-20260601T053440Z-3-001/dataset/employee.csv",
    header=True,
    inferSchema=True,
    sep="|",
)
employee_df.filter(col("company")=="Infosys").select(col("name")).display()

# %% [markdown]
# ### Lowercase sensitive name function

# %%
from pyspark.sql.functions import lower
employee_df.filter(lower("company")=="cisco").select(col("name")).display()

# %% [markdown]
# ###Use multiple filter in column

# %%
employee_df = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sendbox/dataset-20260601T053440Z-3-001/dataset/employee.csv",
    header=True,
    inferSchema=True,
    sep="|",
)
employee_df.filter(col("desig").isin(["Team Lead","Developer"])).display()

# %% [markdown]
# ### Grouping,Aggregations and Sorting

# %%
#employee_df.groupBy("gen").count().sort(col("count").desc()).display()
employee_df = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sendbox/dataset-20260601T053440Z-3-001/dataset/employee.csv",
    header=True,
    inferSchema=True,
    sep="|",
)
employee_df.groupBy("gen").count().orderBy(col("count"), decending=False).display()

# %% [markdown]
# # Derive new columns

# %%
from pyspark.sql.functions import when
employee_df.withColumn(
    "exp level",
    when(col("exp") >= 10, "senior")
    .wheno(col("exp") >= 5, "junior")
    .when(col("exp") >= 0, "junior")
    .otherwise("Invalid Experience"),
).select("name", "exp", "exp level").display()

# %% [markdown]
# #
