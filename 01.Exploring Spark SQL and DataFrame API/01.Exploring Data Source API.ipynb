# %%
df = spark.read.json ("/Volumes/quickstart_catalog/quickstart_schema/sendbox/dataset-20260601T053440Z-3-001/dataset/sample_dataset/users_004.json",
multiLine=True,
)
df.display ()

# %%
df= spark.read.parquet("/Volumes/quickstart_catalog/quickstart_schema/sendbox/dataset-20260601T053440Z-3-001/dataset/sample_dataset/users.parquet")
df.display ()/Volumes/quickstart_catalog/quickstart_schema/sendbox/dataset-20260601T053440Z-3-001/dataset/sample_dataset/users_002.json

# %%
df = spark.read.csv(
    "/Volumes/quickstart_catalog/quickstart_schema/sendbox/dataset-20260601T053440Z-3-001/dataset/sample_dataset/users_001.dat",
    header=True,
    inferSchema=True,
    sep="|"
)
df.display()

# %%
dfr = spark.read
df = dfr.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sendbox/dataset-20260601T053440Z-3-001/dataset/sample_dataset/users_001.csv",
header = True,
inferSchema = True,
)
df.display()
