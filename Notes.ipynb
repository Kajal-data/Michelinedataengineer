# %% [markdown]
# # DataFrame Write API

# %% [markdown]
# # Handling Bad Records

# %% [markdown]
# ### PERMISIVE(Default)

# %%
spark.read.json (path = "/Volumes/quickstart_catalog/quickstart_schema/sendbox/dataset-20260601T053440Z-3-001/dataset/access_logs.json").display ()

# %% [markdown]
# ### DROPMAILFORMED

# %%
spark.read.json (path = "/Volumes/quickstart_catalog/quickstart_schema/sendbox/dataset-20260601T053440Z-3-001/dataset/access_logs.json",
mode="DROPMALFORMED"
).display ()

# %% [markdown]
# ### FAILFAST

# %%
spark.read.json (path = "/Volumes/quickstart_catalog/quickstart_schema/sendbox/dataset-20260601T053440Z-3-001/dataset/access_logs.json",
mode="FAILFAST"
).display ()
